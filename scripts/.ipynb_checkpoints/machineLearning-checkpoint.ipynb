# %%
#Import Libraries and Read the data
import pandas as pd 
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree


#import xgboost
from sklearn.model_selection import train_test_split

# %%
#import sys
#!{sys.executable} -m pip install xgboost

# install worked but still can't import?

# %% [markdown]
# # Read in data

# %%
taxa = pd.read_csv("/fs/ess/PAS1695/projects/exorien/data/drake-output/2022-03-16/2022-03-16_RA-with-taxonomy.csv")
taxa = taxa.drop(columns=['microbe', 'Taxonomy', 'domain', 'kingdom', 'phylum', 'class', 'order','family', 'species'])
taxa.head()
# Out:
#      sample               genus        exo.ra
# 0  SL204951  g__Gammaretrovirus  1.588590e-09
# 1  SL204955  g__Gammaretrovirus  1.588577e-09
# 2  SL204959  g__Gammaretrovirus  1.580972e-09
# 3  SL204960  g__Gammaretrovirus  1.580962e-09
# 4  SL204966  g__Gammaretrovirus  1.580976e-09

# %%
clin = pd.read_csv("/fs/ess/PAS1695/projects/exorien/data/IO_NOVA_clin.txt",  sep = "\t", header=None)
clin.columns = ["Sample_ID", "Cancer_Type", "OS_Event", "OS", "Response"]
clin = clin[clin['Cancer_Type'] == 'Melanoma'] 
clin = clin.drop(columns=["Cancer_Type", "OS_Event", "OS"])
clin.head()
# Out:
#    Sample_ID Response
# 79  SL399219        1
# 80  SL399360        1
# 81  SL372342        1
# 82  SL362825        1
# 83  SL362853        1

# %% [markdown]
# # Transform: long to wide

# %%
# summarize
taxa_mel = taxa[taxa['sample'].isin(clin['Sample_ID'])]
taxaSum = taxa_mel.groupby(['sample', 'genus'], as_index=False)['exo.ra'].sum()

# long to wide
taxaWide = pd.pivot(taxaSum, index='sample', columns='genus',values='exo.ra')
taxaWide.head()
# Out:
# genus     g__Abiotrophia  g__Abyssicoccus  g__Acetilactobacillus  \
# sample
# SL251102    1.607202e-09     1.579746e-09           1.576725e-09
# SL257956    1.607202e-09     1.579746e-09           1.576725e-09
# SL271795    1.607205e-09     1.579750e-09           1.576728e-09
# SL310764    1.579697e-09     1.564247e-09           1.576641e-09
# SL310813    1.581751e-09     1.588023e-09           1.576136e-09
#
# genus     g__Acetivibrio  g__Acetomicrobium  g__Acholeplasma  \
# sample
# SL251102    3.180566e-09       1.583079e-09     3.151087e-09
# SL257956    3.180567e-09       1.583079e-09     3.151087e-09
# SL271795    3.180573e-09       1.583082e-09     3.151094e-09
# SL310764    3.149183e-09       1.572225e-09     3.145508e-09
# SL310813    3.167039e-09       1.581881e-09     3.155622e-09
#
# genus     g__Achromobacter  g__Acidianus  g__Acidibrevibacterium  \
# sample
# SL251102      9.625264e-09  1.577513e-09            1.576350e-09
# SL257956      9.625264e-09  1.577514e-09            1.576350e-09
# SL271795      9.625283e-09  1.577517e-09            1.576353e-09
# SL310764      9.608067e-09  1.575625e-09            1.552914e-09
# SL310813      9.221916e-09  1.577431e-09            1.602051e-09
#
# genus     g__Acidiferrobacter  ...  \
# sample                         ...
# SL251102         1.580575e-09  ...
# SL257956         1.580576e-09  ...
# SL271795         1.580579e-09  ...
# SL310764         1.569752e-09  ...
# SL310813         1.580005e-09  ...
#
# genus     g__unclassified-s__Mycobacterium phage LilMcDreamy  \
# sample
# SL251102                                       1.569211e-09
# SL257956                                       1.569211e-09
# SL271795                                       1.569214e-09
# SL310764                                       1.576462e-09
# SL310813                                       1.575820e-09
#
# genus     g__unclassified-s__Mycobacterium phage Pinnie  \
# sample
# SL251102                                   1.574733e-09
# SL257956                                   1.574733e-09
# SL271795                                   1.574736e-09
# SL310764                                   1.562613e-09
# SL310813                                   1.580558e-09
#
# genus     g__unclassified-s__Mycobacterium phage Saguaro  \
# sample
# SL251102                                    1.576702e-09
# SL257956                                    1.576702e-09
# SL271795                                    1.576705e-09
# SL310764                                    1.576756e-09
# SL310813                                    1.576471e-09
#
# genus     g__unclassified-s__Orpheovirus IHUMI-LCC2  \
# sample
# SL251102                               1.588750e-09
# SL257956                               1.588750e-09
# SL271795                               1.588753e-09
# SL310764                               1.567808e-09
# SL310813                               1.598604e-09
#
# genus     g__unclassified-s__Providencia phage Kokobel1  \
# sample
# SL251102                                   1.576221e-09
# SL257956                                   1.576221e-09
# SL271795                                   1.576224e-09
# SL310764                                   1.577058e-09
# SL310813                                   1.575857e-09
#
# genus     g__unclassified-s__Pseudomonas phage PspYZU01  \
# sample
# SL251102                                   1.577429e-09
# SL257956                                   1.577429e-09
# SL271795                                   1.577432e-09
# SL310764                                   1.573992e-09
# SL310813                                   1.579521e-09
#
# genus     g__unclassified-s__Streptococcus phage 5093  \
# sample
# SL251102                                 1.578461e-09
# SL257956                                 1.578461e-09
# SL271795                                 1.578464e-09
# SL310764                                 1.577273e-09
# SL310813                                 1.577862e-09
#
# genus     g__unclassified-s__Yersinia phage phiR1-37  \
# sample
# SL251102                                1.575811e-09
# SL257956                                1.575811e-09
# SL271795                                1.575814e-09
# SL310764                                1.575824e-09
# SL310813                                1.575901e-09
#
# genus     g__unclassified-s__endosymbiont of unidentified scaly snail isolate Monju  \
# sample
# SL251102                                       1.575125e-09
# SL257956                                       1.575125e-09
# SL271795                                       1.575128e-09
# SL310764                                       1.569065e-09
# SL310813                                       1.551818e-09
#
# genus     g__unclassified-s__uncultured crAssphage
# sample
# SL251102                              1.586441e-09
# SL257956                              1.586441e-09
# SL271795                              1.586444e-09
# SL310764                              1.580228e-09
# SL310813                              1.581905e-09
#
# [5 rows x 882 columns]

# %%
clin = clin.set_index('Sample_ID')

# %% [markdown]
# # Reduce Dimensionality

# %%
# Create correlation matrix
corr_matrix = taxaWide.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.2 - why are the correlation values so low?
to_drop = [column for column in upper.columns if any(upper[column] > 0.2)]

# Drop features 
taxaWide.drop(to_drop, axis=1, inplace=True)

taxaWide.head()
# Out:
# genus     g__Abiotrophia  g__Acetilactobacillus  g__Acidipropionibacterium  \
# sample
# SL251102    1.607202e-09           1.576725e-09               4.730165e-09
# SL257956    1.607202e-09           1.576725e-09               4.730165e-09
# SL271795    1.607205e-09           1.576728e-09               4.730174e-09
# SL310764    1.579697e-09           1.576641e-09               4.723918e-09
# SL310813    1.581751e-09           1.576136e-09               4.730858e-09
#
# genus     g__Acinetobacter  g__Actinobacillus  g__Aeoliella  \
# sample
# SL251102      7.726204e-08       4.727348e-09  1.531501e-09
# SL257956      9.860461e-08       4.727348e-09  1.531501e-09
# SL271795      8.293647e-08       4.727357e-09  1.531504e-09
# SL310764      3.390758e-07       4.725720e-09  1.557719e-09
# SL310813      1.020411e-07       4.695178e-09  1.588949e-09
#
# genus     g__Aggregatibacter  g__Agrococcus   g__Ahniella  g__Akkermansia  \
# sample
# SL251102        3.121255e-09   1.572344e-09  1.580080e-09    3.237919e-09
# SL257956        3.121255e-09   1.572344e-09  1.580080e-09    3.237919e-09
# SL271795        3.121261e-09   1.572347e-09  1.580083e-09    3.237925e-09
# SL310764        3.137450e-09   1.571506e-09  1.576153e-09    3.068309e-09
# SL310813        3.104190e-09   1.565322e-09  1.587632e-09    3.162649e-09
#
# genus     ...    g__Babesia  g__Butyrivibrio  g__Caulifigura  g__Clostridium  \
# sample    ...
# SL251102  ...  1.207501e-09     1.588287e-09    1.571530e-09    7.700638e-08
# SL257956  ...  1.207501e-09     1.588287e-09    1.571530e-09    6.782715e-08
# SL271795  ...  1.207503e-09     1.588290e-09    1.571533e-09    6.782728e-08
# SL310764  ...  1.548185e-09     1.579836e-09    1.571344e-09    6.792193e-08
# SL310813  ...  1.095776e-09     1.564701e-09    1.552558e-09    6.830757e-08
#
# genus     g__Egibacter  g__Erythrobacter  g__Haemophilus  g__Halocella  \
# sample
# SL251102  1.489502e-09      7.844192e-09    7.854024e-09  1.561393e-09
# SL257956  1.489502e-09      7.844192e-09    7.854024e-09  1.561393e-09
# SL271795  1.489505e-09      7.844207e-09    7.854039e-09  7.275163e-09
# SL310764  1.603478e-09      7.778728e-09    7.918088e-09  1.571209e-09
# SL310813  2.697649e-09      7.982564e-09    7.880371e-09  1.582945e-09
#
# genus     g__Kitasatospora  g__Torulaspora
# sample
# SL251102      4.153039e-09    4.363671e-08
# SL257956      1.218520e-08    1.612750e-09
# SL271795      4.153047e-09    1.612753e-09
# SL310764      4.752807e-09    1.579921e-09
# SL310813      4.510471e-09    1.562339e-09
#
# [5 rows x 28 columns]

# %% [markdown]
# # Split into testing and training

# %%
x = taxaWide
y = clin

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, shuffle=True)

# %%
x_train.head()
# Out:
# genus     g__Abiotrophia  g__Acetilactobacillus  g__Acidipropionibacterium  \
# sample
# SL362832    1.576440e-09           1.576440e-09               4.729321e-09
# SL362829    1.576441e-09           1.576441e-09               4.729322e-09
# SL359722    1.607215e-09           1.576738e-09               4.730204e-09
# SL337489    1.585010e-09           1.576328e-09               4.725365e-09
# SL383153    1.607217e-09           1.576740e-09               4.730210e-09
#
# genus     g__Acinetobacter  g__Actinobacillus  g__Aeoliella  \
# sample
# SL362832      1.250962e-07       4.729321e-09  1.576440e-09
# SL362829      5.885502e-07       4.729322e-09  1.576441e-09
# SL359722      1.119707e-07       4.727387e-09  1.531514e-09
# SL337489      8.652417e-08       4.691603e-09  1.570070e-09
# SL383153      7.634352e-08       4.727393e-09  1.531516e-09
#
# genus     g__Aggregatibacter  g__Agrococcus   g__Ahniella  g__Akkermansia  \
# sample
# SL362832        3.152881e-09   1.576440e-09  1.576440e-09    1.645703e-07
# SL362829        3.152881e-09   1.576441e-09  1.576441e-09    3.152881e-09
# SL359722        3.121281e-09   1.572357e-09  1.580093e-09    3.237946e-09
# SL337489        3.088902e-09   1.560413e-09  1.587334e-09    6.832816e-09
# SL383153        3.121285e-09   1.572359e-09  1.580095e-09    3.237950e-09
#
# genus     ...    g__Babesia  g__Butyrivibrio  g__Caulifigura  g__Clostridium  \
# sample    ...
# SL362832  ...  1.576440e-09     1.576440e-09    1.576440e-09    6.778694e-08
# SL362829  ...  1.576441e-09     1.576441e-09    1.576441e-09    6.778695e-08
# SL359722  ...  1.098144e-08     1.588301e-09    1.571544e-09    7.621764e-08
# SL337489  ...  7.901192e-09     1.568062e-09    1.547530e-09    7.052212e-08
# SL383153  ...  1.207512e-09     1.588303e-09    1.571546e-09    1.053660e-07
#
# genus     g__Egibacter  g__Erythrobacter  g__Haemophilus  g__Halocella  \
# sample
# SL362832  1.576440e-09      2.247828e-08    7.882202e-09  1.576440e-09
# SL362829  1.576441e-09      7.882203e-09    7.882203e-09  1.576441e-09
# SL359722  1.489515e-09      7.844258e-09    7.854090e-09  1.561406e-09
# SL337489  1.488030e-09      3.663022e-08    7.915997e-09  1.577683e-09
# SL383153  1.489517e-09      7.844268e-09    7.854100e-09  1.561408e-09
#
# genus     g__Kitasatospora  g__Torulaspora
# sample
# SL362832      4.729321e-09    1.576440e-09
# SL362829      4.729322e-09    1.576441e-09
# SL359722      4.153074e-09    1.612764e-09
# SL337489      4.526651e-09    1.565780e-09
# SL383153      4.153079e-09    1.612766e-09
#
# [5 rows x 28 columns]

# %% [markdown]
# # Model

# %%
classifiers =[]

#model1 = xgboost.XGBClassifier()
#classifiers.append(model1)

model2 = svm.SVC()
classifiers.append(model2)

model3 = tree.DecisionTreeClassifier()
classifiers.append(model3)

model4 = RandomForestClassifier()
classifiers.append(model4)

# %%
for clf in classifiers:
    clf.fit(x_train, y_train)
    y_pred= clf.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    print("Accuracy of %s is %s"%(clf, acc))
    cm = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix of %s is %s"%(clf, cm))
# Out:
# Accuracy of SVC() is 0.4
# Confusion Matrix of SVC() is [[0 9]
#  [0 6]]
# Accuracy of DecisionTreeClassifier() is 0.4666666666666667
# Confusion Matrix of DecisionTreeClassifier() is [[1 8]
#  [0 6]]
# Accuracy of RandomForestClassifier() is 0.4
# Confusion Matrix of RandomForestClassifier() is [[0 9]
#  [0 6]]
# /apps/python/3.9-2022.05/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/slurmtmp.13073214/ipykernel_213367/38144895.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(x_train, y_train)

# %%
classifiers
# Out:
# [SVC(), DecisionTreeClassifier(), RandomForestClassifier()]

# %% [markdown]
# # Artifically expand dataset?

# %% [markdown]
# # Look at all cancer types?
